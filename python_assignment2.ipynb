# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajax121/iNeuron/blob/master/python_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Create the below pattern using nested for loop in Python.
#
#
#
#
#
#
#
#
#
#
# ![pattern.JPG](data:image/jpeg;base64,...)

# %%
b = int(input("Enter breadth of points needed for pattern formation: "))
for i in range(b):
  for j in range(i+1):
    print('*',end=" ")
  print("\n")

for i in range(b,0,-1):
  for j in range(0,i-1):
    print('*',end=" ")
  print("\n")
# Out:
# Enter breadth of points needed for pattern formation: 5
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * *
#
# * * *
#
# * *
#
# *

# %% [markdown]
# 2. Write a Python program to reverse a word after accepting the input from the user.

# %%
x = input("Enter string: ")
print("Reversed string : ",x[::-1])
# Out:
# Enter string: ineuron
# Reversed string :  norueni
